# %%
# tuple

atuple = (3, "asdf", 4.3)
atuple

# %%
type(atuple)

# %%
atuple = 3, "asdf", 4.3
type(atuple)

# %%
atuple * 3

# %%
alist = [3, "asdf", 4.3]
type(alist)

# %%
# list is mutable
# tuple is immutable

print(alist)
alist[0] = 13.13
print(alist)

# %%
alist[0]

# %%
print(atuple)
# atuple[0] = 13.13
print(atuple)

# %%
atuple[0]
