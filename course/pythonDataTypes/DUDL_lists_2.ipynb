# %%
lst = [1, 2, 3, 4, 5]

print(lst)

lst.append(7)
print(lst)

# %%
lst.insert(2, 9)
print(lst)

# %%
lst.insert(4, "qwerty")
print(lst)

# %%
#
lst.remove(9)
print(lst)

# %%
# lst.remove(19)
# print(lst)

# %%
# lst.sort()
# lst

# %%
# Exercise: remove the string 'qwerty' from the list and sort it.
lst.remove("qwerty")
lst.sort()
print(lst)

# %%
lst.sort(reverse=True)
print(lst)
