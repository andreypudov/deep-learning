# %%
# list
aList = [4, 5, 6, 2, 0, 3]
aList

# %%
strList = ["hi", "my", "name", "is", "Andrey"]
type(strList)

# %%
mixList = [8, 5.01, "test", 50.1, [1, 2, 3]]
mixList

# %%
listOfLists = [
    [1, 2, 3],  # this is a list
    1,  # this is a number
    "2",  # this is a string
    [3, 4, 5],
    6,
]
listOfLists

# %%
# 4 in list
4 in aList

# %%
40 in aList

# %%
aList + strList

# %%
aList * 3

# %%
strList * 3

# %%
# method
print(aList)

# %%
len(aList)

# %%
aList.append(-100)
print(aList)

# %%
aList.append(-100)
print(aList)

# %%
aList.sort()
print(aList)

# %%
# Exercise: Use a list method to find the number of "-100" in aList.
aList.count(-100)

# %%
counter = 0
for item in aList:
    if item == -100:
        counter += 1
counter
