# %%
import numpy as np
import pandas as pd

# create random data
var1 = np.random.randn(100) * 5 + 20
var2 = np.random.randn(100) > 0

# variable labels
labels = ["Temp (C)", "Ice cream"]

# put them together into a dictionary
D = {labels[0]: var1, labels[1]: var2}

# import the dictionary into a pandas dataframe
df = pd.DataFrame(data=D)

# %%
type(df)

# %%
df

# %%
df.head()

# %%
df.count()

# %%
df.mean()

# %%
# Exercise
# create a pandas dataframe with
# - integers going from 0 to 10, their square, and their log

numbers = np.random.randint(0, 10, 100)
squares = numbers**2
logs = np.log(numbers)

data = {"Number": numbers, "Squaare": squares, "Log": logs}
df = pd.DataFrame(data)

df

# %%
nums = np.array(range(11))

df = pd.DataFrame({"Number": nums, "Squaare": nums**2, "Log": np.log(nums)})
df

# warning
# error
