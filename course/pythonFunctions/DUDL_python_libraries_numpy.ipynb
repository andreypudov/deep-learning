# %%
import numpy as np

numbers = [1, 2, 3, 4, 5]

np.mean(numbers)

# %%
np.linspace(1, 7, 5)

# %%
x = np.linspace(1, 7, 5)
type(x)

# %%
numbers_np = np.array(numbers)
print(type(numbers))
print(type(numbers_np))

# %%
print(numbers_np.min())

# %%
print(np.min(numbers_np))

# %%
print(np.min(numbers))

# %%
np.min(numbers)

# %%
# in-place
# out-of-place / not in-place operations

n = [4, 3, 5, 2, 6, 1, 7]

print(n)
n.sort()
print(n)

# %%
n = [4, 3, 5, 2, 6, 1, 7]
nn = np.array(n)

print(nn)
nn.sort()
print(nn)

# %%
n = [4, 3, 5, 2, 6, 1, 7]
nn = np.array(n)

print(nn)
np.sort(nn)
print(nn)

# %%
n = [4, 3, 5, 2, 6, 1, 7]
nn = np.array(n)

print(nn)
nns = np.sort(nn)
print(nns)
