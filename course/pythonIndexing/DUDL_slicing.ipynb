# %%
# slicing

a = range(5, 11)
a

# %%
type(a)

# %%
a = list(range(5, 11))
a

# %%
a[2]

# %%
a[0:2]

# %%
a[:3]

# %%
a[1:3]

# %%
a[3:]

# %%
a[:]

# %%
a[::]

# %%
a[::2]

# %%
a[1::2]

# %%
a[1::4]

# %%
a[1::6]

# %%
a[::]

# %%
a[:]

# %%
start = 0
stop = 3
skip = 1

a[start:stop:skip]

# %%
# revere a list
a[::-1]

# %%
# Exercise
text = "345dfyug ecin a si ekiM 93845d"

# use slicing to write "Mike is a nice guy" from the list 'text'
print(text[-8:4:-1])

# 8 from the right
# 4 from the left
