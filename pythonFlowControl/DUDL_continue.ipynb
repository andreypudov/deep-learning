# %%
for i in range(10):
    print(i)

# %%
for i in range(10):
    if i % 2 == 0:
        continue
    print(i)

# %%
text = "Hello, my name is AndreY"

for i in text:
    if i.lower() in "aeiou":
        continue
    print(i)
