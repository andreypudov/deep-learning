# %%
# tuple

atuple = (3, 'asdf', 4.3)
atuple
# Out:
# (3, 'asdf', 4.3)

# %%
type(atuple)
# Out:
# tuple

# %%
atuple = 3, 'asdf', 4.3
type(atuple)
# Out:
# tuple

# %%
atuple * 3
# Out:
# (3, 'asdf', 4.3, 3, 'asdf', 4.3, 3, 'asdf', 4.3)

# %%
alist = [3, 'asdf', 4.3]
type(alist)
# Out:
# list

# %%
# list is mutable
# tuple is immutable

print(alist)
alist[0] = 13.13
print(alist)
# Out:
# [3, 'asdf', 4.3]
# [13, 'asdf', 4.3]

# %%
alist[0]
# Out:
# 13

# %%
print(atuple)
# atuple[0] = 13.13
print(atuple)
# Out:
# (3, 'asdf', 4.3)
# (3, 'asdf', 4.3)

# %%
atuple[0]
# Out:
# 3
