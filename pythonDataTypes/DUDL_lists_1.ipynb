# %%
# list
aList = [4, 5, 6, 2, 0, 3]
aList
# Out:
# [4, 5, 6, 2, 0, 3]

# %%
strList = ["hi", "my", "name", "is", "Andrey"]
type(strList)
# Out:
# list

# %%
mixList = [8, 5.01, "test", 50.1, [1, 2, 3]]
mixList
# Out:
# [8, 5.01, 'test', 50.1, [1, 2, 3]]

# %%
listOfLists = [
    [1, 2, 3],  # this is a list
    1,  # this is a number
    "2",  # this is a string
    [3, 4, 5],
    6,
]
listOfLists
# Out:
# [[1, 2, 3], 1, '2', [3, 4, 5], 6]

# %%
# 4 in list
4 in aList
# Out:
# True

# %%
40 in aList
# Out:
# False

# %%
aList + strList
# Out:
# [4, 5, 6, 2, 0, 3, 'hi', 'my', 'name', 'is', 'Andrey']

# %%
aList * 3
# Out:
# [4, 5, 6, 2, 0, 3, 4, 5, 6, 2, 0, 3, 4, 5, 6, 2, 0, 3]

# %%
strList * 3
# Out:
# ['hi',
#  'my',
#  'name',
#  'is',
#  'Andrey',
#  'hi',
#  'my',
#  'name',
#  'is',
#  'Andrey',
#  'hi',
#  'my',
#  'name',
#  'is',
#  'Andrey']

# %%
# method
print(aList)
# Out:
# [4, 5, 6, 2, 0, 3]

# %%
len(aList)
# Out:
# 6

# %%
aList.append(-100)
print(aList)
# Out:
# [4, 5, 6, 2, 0, 3, -100]

# %%
aList.append(-100)
print(aList)
# Out:
# [4, 5, 6, 2, 0, 3, -100, -100]

# %%
aList.sort()
print(aList)
# Out:
# [-100, -100, 0, 2, 3, 4, 5, 6]

# %%
# Exercise: Use a list method to find the number of "-100" in aList.
aList.count(-100)
# Out:
# 2

# %%
counter = 0
for item in aList:
    if item == -100:
        counter += 1
counter
# Out:
# 2
