# %%
# boolean

t = True
f = False

# %%
# True = 234
# Out:
#   Cell In[2], line 1
#     True = 234
#     ^
# SyntaxError: cannot assign to True

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# f          bool    False
# t          bool    True

# %%
4 == 4
# Out:
# True

# %%
4 == 4.1
# Out:
# False

# %%
4 == 4.0
# Out:
# True

# %%
test = 4 == 4.0
print(test)
# Out:
# True

# %%
test = 4 == 45
print(test)
# Out:
# False

# %%
4 > 5
# Out:
# False

# %%
4 < 5
# Out:
# True

# %%
7 < 7
# Out:
# False

# %%
7 <= 7
# Out:
# True

# %%
7 != 7
# Out:
# False

# %%
7 != 8
# Out:
# True

# %%
# conjuctive comparison

x = 10
x > 5 and x < 15
# Out:
# True

# %%
x = 10
y = 16

x > 5 and y > 15 and (x + y) < 50
# Out:
# True

# %%
x > 5 or y < 15
# Out:
# True

# %%
str(5)
# Out:
# '5'

# %%
float("5.9")
# Out:
# 5.9

# %%
bool(0)
# Out:
# False

# %%
bool(0.1)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
bool(-100)
# Out:
# True

# %%
bool("true")
# Out:
# True

# %%
bool("False")
# Out:
# True

# %%
bool(" ")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
# Exercise
# input from the user 3 numbers: a, b, c
# check whether c**2 == a**2 + b**2
# print out the result

a = float(input("Please enter the length of side a: "))
b = float(input("Please enter the length of side b: "))
c = float(input("Please enter the length of side c: "))

test = c**2 == a**2 + b**2

print("The expression is " + "correct" if test else "incorrect")
# Out:
# The expression is correct
