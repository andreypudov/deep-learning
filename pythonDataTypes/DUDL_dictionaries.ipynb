# %%
# dictionary: key/vaue pairs
D = dict()
D
# Out:
# {}

# %%
# [] lists
# () tuples
# {} dictionaries

# %%
# key / value
D['name'] = 'Andrey'
D
# Out:
# {'name': 'Andrey'}

# %%
D['ageRange'] = [20, 50]

# %%
E = {'ageRange': [20, 50], 'name': 'Andrey', 'favColor': 'green'}
E
# Out:
# {'ageRange': [20, 50], 'name': 'Andrey', 'favColor': 'green'}

# %%
D['name']
# Out:
# 'Andrey'

# %%
D['name'] = 'Andrey Pudov'

# %%
D['name']
# Out:
# 'Andrey Pudov'

# %%
E.keys()
# Out:
# dict_keys(['ageRange', 'name', 'favColor'])

# %%
'name' in E
# Out:
# True

# %%
'Andrey' in E
# Out:
# False

# %%
E.values()
# Out:
# dict_values([[20, 50], 'Andrey', 'green'])

# %%
E.items()
# Out:
# dict_items([('ageRange', [20, 50]), ('name', 'Andrey'), ('favColor', 'green')])

# %%
# Exercise
# Input two numbers from the user.
# Create a dictionary with 3 keys: 'firstNum', 'secondNum', 'product'

firstNumber  = float(input('Please enter the value of the first number: '))
secondNumber = float(input('Please enter the value of the second number: '))

productDictionary = {
   'firstNum': firstNumber,
   'secondNum': secondNumber,
   'product': firstNumber * secondNumber
}

print(productDictionary)
# Out:
# {'firstNum': 2.0, 'secondNum': 3.0, 'product': 6.0}
