# %%
7 + 6
# Out:
# 13

# %%
a = 4

# %%
b = 5

# %%
a
b
# Out:
# 5

# %%
print(a)
print(b)
# Out:
# 4
# 5

# %%
# this code cell inspects the value of a and b, which are 4 and 5 respectively
print(a)
print(b)
# Out:
# 4
# 5

# %%
c = 7
d = 7.0

print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>

# %%
e = "hello"
f = "My 'name' is Andrey"

type(f)
# Out:
# str

# %%
aVariableName = 10
filterOrder   = 18
user_name     = 'Andrey'
param4modelA  = 43.58745

# not@allowed = 324
# 3casdf = 4
_3casdf = 4

# %whos
# Out:
# Variable        Type     Data/Info
# ----------------------------------
# a               int      4
# aVariableName   int      10
# b               int      5
# c               int      7
# d               float    7.0
# e               str      hello
# f               str      My name is Andrey
# filterOrder     int      18
# param4modelA    float    43.58745
# user_name       str      Andrey

# %%
# multiple assignment
varA = 3
varB = "test"

print(varA)
print(varB)
# Out:
# 3
# test

# %%
varA, varB = 3, "test"

print(varA)
print(varB)
# Out:
# 3
# test

# %%
# Exercise!
# Can you overwrite existing variables?
# - using the same variable type?
# - using a different variable type?

varA = 10
print(type(varA))
print(varA)

varA = 20
print(type(varA))
print(varA)

varA = "Now I am a string"
print(type(varA))
print(varA)
# Out:
# <class 'int'>
# 10
# <class 'int'>
# 20
# <class 'str'>
# Now I am a string
