# %% [markdown]
# # Softmax
#
# The softmax function is a mathematical function that converts a vector of real numbers into a probability distribution.
#
# The softmax function is defined as follows:
# $$\sigma_i = \frac{e^{z_i}}{\sum e^z}$$
#
# Where $z$ is the input vector and $\sigma$ is the output vector.

# %% [markdown]
# ## Example
#
# $$ z = \{1, 2, 3\} $$
# $$ e^z = \{e^1, e^2, e^3\} = \{2.718, 7.389, 20.086\} $$
# $$ \sum e^z = 2.718 + 7.389 + 20.086 = 30.193 $$
# $$ \sigma = \{\frac{2.718}{30.193}, \frac{7.389}{30.193}, \frac{20.086}{30.193}\} = \{0.090, 0.245, 0.665\} $$
