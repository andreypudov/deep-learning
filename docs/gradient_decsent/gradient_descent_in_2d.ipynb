# %% [markdown]
# # Gradient descent in 2D
#
# $$
# \begin{align*}
# f(x, y) &= 3(1-x)^{2}e^{-x^2-(y+1)^2} - 10\left(\frac{x}{5} - x^3 - y^5\right)e^{-x^2-y^2} - \frac{1}{3}e^{-(x+1)^2-y^2} \\
# \end{align*}

# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline

from IPython.display import display, Math

matplotlib_inline.backend_inline.set_matplotlib_formats("svg")

# %%
x = sym.symbols("x")
y = sym.symbols("y")

fxy_sym = (
    3 * (1 - x) ** 2 * sym.E ** (-(x**2) - (y + 1) ** 2)
    - 10 * (x / 5 - x**3 - y**5) * sym.E ** (-(x**2) - y**2)
    - sym.Rational(1, 3) * sym.E ** (-((x + 1) ** 2) - y**2)
)

df_x = sym.diff(fxy_sym, x)
df_y = sym.diff(fxy_sym, y)

display(Math(sym.latex(fxy_sym)))
display(Math(sym.latex(df_x)))
display(Math(sym.latex(df_y)))

# %%
f = sym.lambdify((x, y), fxy_sym, "numpy")

xs = np.linspace(-3, 3, 400)
ys = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(xs, ys)
Z = f(X, Y)

# Plot
plt.figure(figsize=(6, 5))
plt.imshow(Z, extent=[-3, 3, -3, 3], origin="lower", cmap="viridis")
plt.colorbar(label="f(x, y)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Heatmap of f(x, y)")
plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection="3d")

ax.plot_surface(X, Y, Z, cmap="viridis", linewidth=0, antialiased=True)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")
ax.set_title("3D Surface Plot of f(x, y)")

# %%
plt.figure(figsize=(6, 5))
plt.contour(X, Y, Z, levels=30, cmap="viridis")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Contour Plot of f(x, y)")
plt.colorbar()
plt.show()
