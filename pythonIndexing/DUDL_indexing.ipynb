# %%
# indexing

alist = [4, 6, 2, -6, "qwerty", 10.01]

alist[3]
# Out:
# -6

# %%
alist[0]
# Out:
# 4

# %%
alist[4]
# Out:
# 'qwerty'

# %%
# alist[4.5]

# %%
idx = 4.0
alist[int(idx)]
# Out:
# 'qwerty'

# %%
alist[len(alist) - 1]
# Out:
# 10.01

# %%
alist[-1]
# Out:
# 10.01

# %%
alist[-2]
# Out:
# 'qwerty'

# %%
idx = [3, 5]
# alist[idx]

# %%
alist = [4, 6, 2, -6, [10, 20, 30], 10.01]
alist
# Out:
# [4, 6, 2, -6, [10, 20, 30], 10.01]

# %%
alist[4]
# Out:
# [10, 20, 30]

# %%
alist[4][1]
# Out:
# 20

# %%
# Exercise
# get the attribute of Penguin from this list
listlist = [4, "hi", [5, 4, 3], "yo", {"Squirrel": "cute", "Penguin": "Yammy"}]

listlist[-1]["Penguin"]
# Out:
# 'Yammy'
