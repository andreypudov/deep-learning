# %%
# slicing

a = range(5, 11)
a
# Out:
# range(5, 11)

# %%
type(a)
# Out:
# range

# %%
a = list(range(5, 11))
a
# Out:
# [5, 6, 7, 8, 9, 10]

# %%
a[2]
# Out:
# 7

# %%
a[0:2]
# Out:
# [5, 6]

# %%
a[:3]
# Out:
# [5, 6, 7]

# %%
a[1:3]
# Out:
# [6, 7]

# %%
a[3:]
# Out:
# [8, 9, 10]

# %%
a[:]
# Out:
# [5, 6, 7, 8, 9, 10]

# %%
a[::]
# Out:
# [5, 6, 7, 8, 9, 10]

# %%
a[::2]
# Out:
# [5, 7, 9]

# %%
a[1::2]
# Out:
# [6, 8, 10]

# %%
a[1::4]
# Out:
# [6, 10]

# %%
a[1::6]
# Out:
# [6]

# %%
a[::]
# Out:
# [5, 6, 7, 8, 9, 10]

# %%
a[:]
# Out:
# [5, 6, 7, 8, 9, 10]

# %%
start = 0
stop = 3
skip = 1

a[start:stop:skip]
# Out:
# [5, 6, 7]

# %%
# revere a list
a[::-1]
# Out:
# [10, 9, 8, 7, 6, 5]

# %%
# Exercise
text = "345dfyug ecin a si ekiM 93845d"

# use slicing to write "Mike is a nice guy" from the list 'text'
print(text[-8:4:-1])

# 8 from the right
# 4 from the left
# Out:
# Mike is a nice guy
